# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-изучение-данных" data-toc-modified-id="Загрузка-и-изучение-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка и изучение данных</a></span></li><li><span><a href="#Проверка-формулы-вычисления-эффективности-обогащения" data-toc-modified-id="Проверка-формулы-вычисления-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка формулы вычисления эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобратока-данных" data-toc-modified-id="Предобратока-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобратока данных</a></span><ul class="toc-item"><li><span><a href="#Работаем-с-обучающей-выборкой" data-toc-modified-id="Работаем-с-обучающей-выборкой-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Работаем с обучающей выборкой</a></span></li><li><span><a href="#Работаем-с-тестовой-выборкой" data-toc-modified-id="Работаем-с-тестовой-выборкой-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Работаем с тестовой выборкой</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Исследование-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исследование изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрацию-всех-веществ-на-разных-стадиях" data-toc-modified-id="Исследование-суммарной-концентрацию-всех-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрацию всех веществ на разных стадиях</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Дополнительная-подготовка-данных-к-обучению" data-toc-modified-id="Дополнительная-подготовка-данных-к-обучению-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Дополнительная подготовка данных к обучению</a></span></li><li><span><a href="#Функция-для-вычисления-sMAPE" data-toc-modified-id="Функция-для-вычисления-sMAPE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для вычисления sMAPE</a></span></li><li><span><a href="#Обучение-модели-для-предсказания-эффективность-обогащения-чернового-концентрата" data-toc-modified-id="Обучение-модели-для-предсказания-эффективность-обогащения-чернового-концентрата-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение модели для предсказания эффективность обогащения чернового концентрата</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li></ul></li><li><span><a href="#Обучение-модели-для-предсказания-эффективность-обогащения-финального-концентрата" data-toc-modified-id="Обучение-модели-для-предсказания-эффективность-обогащения-финального-концентрата-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Обучение модели для предсказания эффективность обогащения финального концентрата</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li></ul></li><li><span><a href="#Тестирование-моделей" data-toc-modified-id="Тестирование-моделей-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Тестирование моделей</a></span><ul class="toc-item"><li><span><a href="#Проверим-модель-на-адекватность-(сравнение-с-DummyRegressor)" data-toc-modified-id="Проверим-модель-на-адекватность-(сравнение-с-DummyRegressor)-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Проверим модель на адекватность (сравнение с DummyRegressor)</a></span></li></ul></li><li><span><a href="#Расчет-итогового-sMAPE" data-toc-modified-id="Расчет-итогового-sMAPE-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Расчет итогового sMAPE</a></span></li></ul></li><li><span><a href="#Общий-вывод-по-проекту" data-toc-modified-id="Общий-вывод-по-проекту-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод по проекту</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# **План работ**
#
# 1. Загрузить данные и подготовить данные к анализу:
#     - Проверить, что эффективность обогащения рассчитана правильно: вычислить её на обучающей выборке для признака rougher.output.recovery; найдите MAE между расчетами и значением признака.
#     - Проанализировать признаки, недоступные в тестовой выборке.
#     - Провести предобработку данных.
# 2. Провести анализ данных:
#     - Исследовать изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки. Описать выводы.
#     - Проанализировать распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#     - Исследовать суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# 3. Построить модель прогнозирования:
#     - Написать функция для вычисления итогового sMAPE
#     - Обучить разные модели и оцените их качество кросс-валидацией.
#     - Выберать лучшую модель и проверить её на тестовой выборке. Описать выводы.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_absolute_error, make_scorer

# %% [markdown]
# ### Загрузка и изучение данных

# %%
# загружаем датасеты
try:
    data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv', index_col='date')
    data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv', index_col='date')
    data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv', index_col='date')
except:
    data_train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv', index_col='date')
    data_test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv', index_col='date')
    data_full = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv', index_col='date')

# %%
# описание данных в каждом датасете
for dataset in [data_train, data_test, data_full]:
    dataset.info()
    print('\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %%
# посмотрим в каком соотношение данные разделены на train и test
display(round(len(data_test) / len(data_full), 2))
display(round(len(data_train) / len(data_full), 2))
# Out:
# 0.27
# 0.73

# %% [markdown]
# **Первичные выводы о данных:**
# - В данных содержаться параметры, описывающие каждый этап получения золота из руды.
# - **Данные индексируются датой и временем получения информации (признак date)**.
# - **Не все параметры из полных данных и обучающих данных есть в тестовых данных**. Это требует дополнительного изучения.
# - Данные разделены на обучающую и тестовую выборки в соотношении 73 / 27. Это подходящее для обучения и проверки соотношение.

# %% [markdown]
# ### Проверка формулы вычисления эффективности обогащения

# %%
# расчитаем эффективность на обучающей выборке для признака rougher.output.recovery
C = data_train['rougher.output.concentrate_au']
F = data_train['rougher.input.feed_au']
T = data_train['rougher.output.tail_au']

conculated_rougher_output_recovery = ((C * (F - T)) / (F * (C - T))) * 100

# %%
# расчитаем MAE между расчетами и значением признака
'{:.25f}'.format(mean_absolute_error(data_train['rougher.output.recovery'], conculated_rougher_output_recovery))
# Out:
# '0.0000000000000097351234745'

# %% [markdown]
# **Вывод:** Значение MAE почти равно 0, следовательно эффективность обогащения рассчитана правильно. Расхождение между значением rougher.output.recovery расчитанным по формуле и представленным в обучающих данных минимальное.

# %% [markdown]
# ### Анализ признаков, недоступных в тестовой выборке

# %%
# выведем наименования тех признаков, которые недоступны в тестовой выборке
# соберем список таких признаков
features_to_delete = set(data_train.columns) - set(data_test.columns)
features_to_delete
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %%
# уберем из списка на удаление целевые признаки
features_to_delete.remove('final.output.recovery')
features_to_delete.remove('rougher.output.recovery')

# %% [markdown]
# **Выводы:**
# - Все признаки, недоступные в тестовой выборке, как и другие признаки в данных, имеют **тип данных float**.
# - **Все найденные признаки относятся к типу output или calculation**. Это говорит о том, что это параметры, которые не могут быть получены во время самого процесса. Эти данные описывают полученный продукт или какие-то его характеристики. Такие данные не должны участвовать в обучении и предсказании.
# - Уберем ненужные признаки из обучающей выборки после этапа анализа данных

# %% [markdown]
# ### Предобратока данных

# %% [markdown]
# #### Работаем с обучающей выборкой

# %%
def pass_value_barh(df):
    if df.isna().sum().sum() > 0:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind= 'barh', figsize=(30, 25), legend = False, fontsize = 20)
            .set_title('Доля пропусков' + "\n", fontsize = 25)    
        )   
    else:
        print('Пропусков не осталось!')

# %%
# визуализация доли пропусков в каждом столбце
pass_value_barh(data_train)

# %%
# заполняем пропущенные значения первым не пропущенным значением, которое встречается перед ними
data_train.fillna(method='ffill', inplace=True)

# %%
# проверяем, что все пропуски заполнены
pass_value_barh(data_train)
# Out:
# Пропусков не осталось!

# %%
# проверяем, есть ли в данных дубликаты
data_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Работаем с тестовой выборкой

# %%
# визуализация доли пропусков в каждом столбце
pass_value_barh(data_test)

# %%
# заполняем пропущенные значения первым не пропущенным значением, которое встречается перед ними
data_test.fillna(method='ffill', inplace=True)

# %%
# проверяем, что все пропуски заполнены
pass_value_barh(data_test)
# Out:
# Пропусков не осталось!

# %%
# проверяем, есть ли в данных дубликаты
data_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:**
# - **Как в обучающем, так и в тестовом датасете есть пропуски**. Поскольку данные – это просто последовательные этапы процесса (замеры), соседние по времени параметры часто похожи и **можно использовать заполнение предыдущим значением**.
# - **В данных отсутствуют полные дубликаты**.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследование изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %% [markdown]
# Для исследования изменения концентрации будем рассматривать распределения концентрации металлов на разных этапах и медианные значения.

# %%
# вводим переменные для графиков
metals = ['ag', 'pb', 'au']
concentrate_median_feed = [data_full['rougher.input.feed_ag'].median(),
               data_full['rougher.input.feed_pb'].median(),
               data_full['rougher.input.feed_au'].median()]
concentrate_median_rougher = [data_full['rougher.output.concentrate_ag'].median(),
               data_full['rougher.output.concentrate_pb'].median(),
               data_full['rougher.output.concentrate_au'].median()]
concentrate_median_1 = [data_full['primary_cleaner.output.concentrate_ag'].median(),
               data_full['primary_cleaner.output.concentrate_pb'].median(),
               data_full['primary_cleaner.output.concentrate_au'].median()]
concentrate_median_2 = [data_full['final.output.concentrate_ag'].median(),
               data_full['final.output.concentrate_pb'].median(),
               data_full['final.output.concentrate_au'].median()]
stages = ['rougher.input.feed_',
          'rougher.output.concentrate_',
          'primary_cleaner.output.concentrate_',
          'final.output.concentrate_']
stages_names = ['сырье до флотации',
                'черновой концентрат после флотации', 
                'концентрат после 1-й очистки', 
                'финальный концентрат после 2-й очистки']

# %%
# визуализация концентрации на разных этапах
for metal in metals:
    plt.figure(figsize=(11, 6))
    for stage in stages:
        plt.hist(data_full[f'{stage}{metal}'], bins=30, alpha=0.5)
    plt.legend(stages_names)
    plt.title(f'Распределение концентрации {metal} на разных этапах')

# %%
# визуализация изменения средней концентрации металлов на разных этапах процесса
fig = plt.figure(figsize=(13, 8))
ax = fig.add_subplot()
x = np.arange(3)
w = 0.2
ax.bar(x - 1.5*w, concentrate_median_feed, width=w)
ax.bar(x - w/2, concentrate_median_rougher, width=w)
ax.bar(x + w/2, concentrate_median_1, width=w)
ax.bar(x + 1.5*w, concentrate_median_2, width=w)
plt.xticks(x, ['Cеребро', 'Свинец', 'Золото'])
plt.legend(['feed', 'rougher', 'primary_cleaner', 'secondary_cleaner'])
plt.title('Концетрация металлов (Au, Ag, Pb) на различных этапах очистки')
plt.show()

# %% [markdown]
# **Выводы:**
# - Очистка чернового концентрата после флотации (обогащения) проходит в 2 этапа.
# - После обоих этапов наблюдается значительное преобладание золота (Au) над другими металлами, что вполне ожидаемое, ведь именно на получение золота нацелен данный процесс.
# - Процесс флотации увеличивает концентрацию всех металлов по сравнению с их содержанием в сырье.
# - После флотации на каждом этапе очистки концентрация серебра (Ag) падает.
# - После флотации на 1-м этапе очистки концентрация свинца (Pb) растет, а на 2-м этапе почти не меняется по сравнению с 1-м.
# - Концентрация золото значительно увеличивается на каждом этапе очистки.

# %% [markdown]
# ### Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках

# %%
# визуализация распределения размеров гранул сырья до флотации
data_train['rougher.input.feed_size'].hist(density=True, figsize=(10,6), bins=90)
plt.xlim(0, 200)
plt.title('Распределение размеров гранул сырья до флотации на обучающей выборке')
plt.show()

data_test['rougher.input.feed_size'].hist(density=True, figsize=(10,6), bins=90)
plt.xlim(0, 200)
plt.title('Распределение размеров гранул сырья до флотации на тестовой выборке')
plt.show()

# %%
# визуализация распределения размеров гранул сырья после флотации
data_train['primary_cleaner.input.feed_size'].hist(density=True, figsize=(10,6), bins=70)
plt.xlim(4, 15)
plt.title('Распределение размеров гранул сырья после флотации на обучающей выборке')
plt.show()

data_test['primary_cleaner.input.feed_size'].hist(density=True, figsize=(10,6), bins=70)
plt.xlim(4, 15)
plt.title('Распределение размеров гранул сырья после флотации на тестовой выборке')
plt.show()

# %% [markdown]
# **Вывод:** Как до флотации, так и после нее (перед первым этапом очистки) **распределения размеров гранул сырья на обучающей и тестовой выборках очень похожи**. Это говорит о том, что оценку модели можно будет расценивать как достаточно достоверную.

# %% [markdown]
# ### Исследование суммарной концентрацию всех веществ на разных стадиях

# %%
# визуализация распеределения суммарной концентрации всех веществ
chemicals = ['ag', 'pb', 'au', 'sol']
stages = ['rougher.input.feed_',
          'rougher.output.concentrate_',
          'primary_cleaner.output.concentrate_',
          'final.output.concentrate_']
stages_names = ['сырье до флотации', 
                'черновой концентрат после флотации', 
                'концентрат после 1-й очистки', 
                'финальный концентрат после 2-й очистки']
plt.figure(figsize=(11, 6))
for stage in stages:
    features_input_concentrate = []
    for chemical in chemicals:
        features_input_concentrate.append(f'{stage}{chemical}')
    concentration = data_full[features_input_concentrate].sum(axis=1)
    plt.hist(concentration, bins=30, alpha=0.5)
    plt.legend(stages_names)

# %% [markdown]
# **Вывод:**
# - **Распределение суммарной концентрацию всех веществ похоже на разных стадиях**.
# - На всех стадиях **распределение напоминает нормальное с длинным хвостов влево от среднего**.
# - **Имеются аномальные значения, когда суммарная концентрация равна 0**. Такое возможно только если концентрация каждого вещества равна 0. Такие объекты нужно убрать из обучающей выборки.

# %%
# удаляем все объекты, где значение концентрации каких-либо веществ равно 0
features_input_concentrate = []
for stage in stages:
    for chemical in chemicals:
        features_input_concentrate.append(f'{stage}{chemical}')

for col in features_input_concentrate:
    data_train = data_train[data_train[col] > 0]

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13716 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         13716 non-null  float64
#  1   final.output.concentrate_pb                         13716 non-null  float64
#  2   final.output.concentrate_sol                        13716 non-null  float64
#  3   final.output.concentrate_au                         13716 non-null  float64
#  4   final.output.recovery                               13716 non-null  float64
#  5   final.output.tail_ag                                13716 non-null  float64
#  6   final.output.tail_pb                                13716 non-null  float64
#  7   final.output.tail_sol                               13716 non-null  float64
# ...

# %% [markdown]
# **Мы убрали из данных все объекты в которых значение концентрации каких-либо веществ равно 0**. Количество данных уменьшилось лишь на 3%, что не является существенной потерей.

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Дополнительная подготовка данных к обучению

# %% [markdown]
# **Удаляем из обучающей выборки столбцы с признаками, которых нет в тестовой**

# %%
# удаляем из трейна столбцы с признаками, которых нет в тесте
data_train = data_train.drop(columns=features_to_delete, axis = 1)
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13716 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   final.output.recovery                       13716 non-null  float64
#  1   primary_cleaner.input.sulfate               13716 non-null  float64
#  2   primary_cleaner.input.depressant            13716 non-null  float64
#  3   primary_cleaner.input.feed_size             13716 non-null  float64
#  4   primary_cleaner.input.xanthate              13716 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_air      13716 non-null  float64
#  6   primary_cleaner.state.floatbank8_a_level    13716 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_air      13716 non-null  float64
#  8   primary_cleaner.state.floatbank8_b_level    13716 non-null  float64
# ...

# %% [markdown]
# **Делим выборки на features и target**
#
# Целевые признаки, отсутвующие в тестовой выборке, можно извлечь из полного датасета (data_full) по дате и времени.

# %%
# делим выборки на features и target
features_train = data_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1).reset_index(drop=True)
target_train_rougher = data_train['rougher.output.recovery'].reset_index(drop=True)
target_train_final = data_train['final.output.recovery'].reset_index(drop=True)

features_test = data_test.reset_index(drop=True)
target_test_rougher = data_full['rougher.output.recovery'].loc[data_test.index].reset_index(drop=True)
target_test_final = data_full['final.output.recovery'].loc[data_test.index].reset_index(drop=True)

# %% [markdown]
# **Вывод:** Готовы данные для обучения и проверки качества

# %% [markdown]
# ### Функция для вычисления sMAPE

# %%
def smape(y_true, y_pred):
    error = np.abs(y_true - y_pred)
    scale = (np.abs(y_true) + np.abs(y_pred)) / 2
    return np.mean(error / scale) * 100

# %%
smape_scorer = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# ### Обучение модели для предсказания эффективность обогащения чернового концентрата

# %% [markdown]
# #### Дерево решений

# %%
# %%time

parametrs = {'max_depth': range(1, 13)}

model = DecisionTreeRegressor(random_state=42)
# подбор лучших параметров модели
grid = GridSearchCV(model, parametrs, scoring=smape_scorer, verbose=1)
grid.fit(features_train, target_train_rougher)

best_model_tree_rougher = grid.best_estimator_
best_parametrs_tree_rougher = grid.best_params_
best_result_tree_rougher = grid.best_score_
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# CPU times: user 22.4 s, sys: 98.4 ms, total: 22.5 s
# Wall time: 22.6 s

# %%
display(best_result_tree_rougher) # лучший результат sMAPE модели
display(best_parametrs_tree_rougher) # лучшие параметры модели
# Out:
# -7.316661884341511
# {'max_depth': 4}

# %% [markdown]
# #### Случайный лес

# %%
# %%time

parametrs = {'n_estimators': range(30, 101, 10),
              'max_depth': range(1, 10)}

model = RandomForestRegressor(random_state=42)
# подбор лучших параметров модели
grid = GridSearchCV(model, parametrs, scoring=smape_scorer, verbose=2)
grid.fit(features_train, target_train_rougher)

best_model_forest_rougher = grid.best_estimator_
best_parametrs_forest_rougher = grid.best_params_
best_result_forest_rougher = grid.best_score_
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END .......................max_depth=1, n_estimators=30; total time=   1.5s
# [CV] END .......................max_depth=1, n_estimators=30; total time=   1.3s
# [CV] END .......................max_depth=1, n_estimators=30; total time=   1.4s
# [CV] END .......................max_depth=1, n_estimators=30; total time=   1.5s
# [CV] END .......................max_depth=1, n_estimators=30; total time=   1.3s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   1.7s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   2.3s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   1.7s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   2.3s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   2.3s
# [CV] END .......................max_depth=1, n_estimators=50; total time=   2.8s
# ...

# %%
display(best_result_forest_rougher) # лучший результат sMAPE модели
display(best_parametrs_forest_rougher) # лучшие параметры модели
# Out:
# -6.5456365933586245
# {'max_depth': 5, 'n_estimators': 70}

# %% [markdown]
# #### Линейная регрессия

# %%
# %%time

model = LinearRegression()

scores = cross_val_score(model, features_train, target_train_rougher, scoring=smape_scorer, cv=5, verbose=2)

best_model_lin_reg_rougher = model
best_result_lin_reg_rougher = sum(scores)/len(scores)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time=   0.5s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV] END .................................................... total time=   0.1s
# CPU times: user 456 ms, sys: 185 ms, total: 641 ms
# Wall time: 744 ms
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.7s finished

# %%
display(best_result_lin_reg_rougher) # лучший результат sMAPE модели
# Out:
# -7.2700254999570975

# %% [markdown]
# ### Обучение модели для предсказания эффективность обогащения финального концентрата

# %% [markdown]
# #### Дерево решений

# %%
# %%time

parametrs = {'max_depth': range(1, 8)}

model = DecisionTreeRegressor(random_state=42)
# подбор лучших параметров модели
grid = GridSearchCV(model, parametrs, scoring=smape_scorer, verbose=1)
grid.fit(features_train, target_train_final)

best_model_tree_final = grid.best_estimator_
best_parametrs_tree_final = grid.best_params_
best_result_tree_final = grid.best_score_
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# CPU times: user 9.82 s, sys: 136 ms, total: 9.96 s
# Wall time: 11.4 s

# %%
display(best_result_tree_final) # лучший результат sMAPE модели
display(best_parametrs_tree_final) # лучшие параметры модели
# Out:
# -9.418711833416848
# {'max_depth': 3}

# %% [markdown]
# #### Случайный лес

# %%
# %%time

parametrs = {'n_estimators': range(40, 91, 10),
              'max_depth': range(1, 10)}

model = RandomForestRegressor(random_state=42)
# подбор лучших параметров модели
grid = GridSearchCV(model, parametrs, scoring=smape_scorer, verbose=2)
grid.fit(features_train, target_train_final)

best_model_forest_final = grid.best_estimator_
best_parametrs_forest_final = grid.best_params_
best_result_forest_final = grid.best_score_
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END .......................max_depth=1, n_estimators=40; total time=   1.7s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   1.7s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   1.7s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   1.7s
# [CV] END .......................max_depth=1, n_estimators=40; total time=   1.7s
# [CV] END .......................max_depth=1, n_estimators=50; total time=   2.1s
# [CV] END .......................max_depth=1, n_estimators=50; total time=   2.2s
# [CV] END .......................max_depth=1, n_estimators=50; total time=   2.1s
# [CV] END .......................max_depth=1, n_estimators=50; total time=   2.1s
# [CV] END .......................max_depth=1, n_estimators=50; total time=   2.1s
# [CV] END .......................max_depth=1, n_estimators=60; total time=   2.5s
# ...

# %%
display(best_result_forest_final) # лучший результат sMAPE модели
display(best_parametrs_forest_final) # лучшие параметры модели
# Out:
# -9.032869952032389
# {'max_depth': 4, 'n_estimators': 80}

# %% [markdown]
# #### Линейная регрессия

# %%
# %%time

model = LinearRegression()

scores = cross_val_score(model, features_train, target_train_final, scoring=smape_scorer, cv=5, verbose=2)

best_model_lin_reg_final = model
best_result_lin_reg_final = sum(scores)/len(scores)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# CPU times: user 385 ms, sys: 70.7 ms, total: 456 ms
# Wall time: 366 ms
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished

# %%
display(best_result_lin_reg_final) # лучший результат sMAPE модели

# %% [markdown]
# **Вывод по обучению моделей:**
#
# По результатам исследования можно сказать, что **лучшие результаты показывает модель случайного леса**.
#
# При оценке качества кросс-валидацией **при предсказании эффективности обогащения чернового концентрата удалось получить значение метрики sMAPE равное 6.5** при следующих гиперпараметрах: максимальная глубина дерева – 5 и количество деревьев – 70.
#
# При оценке качества кросс-валидацией **при предсказании эффективности обогащения финального концентрата удалось получить значение метрики sMAPE равное 9.0** при следующих гиперпараметрах: максимальная глубина дерева – 4 и количество деревьев – 80.
#
# **Мы не учитаваем минус, который присутствует в значениях sMAPE**, выводимых после кросс-валидации, так как sMAPE не является стандартным значением параметра scoring. sMAPE – это новая функция потерь, созданная с помощью make_scorer. Так как GridSearch и cross_val_score всегда максимизируют метрику, а нам нужно ее минимизаровать, в make_scorer мы добавляем параметр greater_is_better=False (больше - хуже). Тогда в метрике ставится минус. Она все равно максимизируется, но учитывая минус это как раз будет лучшее минимальное значение. Таким образом, **минус подставляется только для оптимизации при переборе и фактическое значение метрики, на самом деле без него**.
#
# Проверим данные модели на тестовой выборке и получим значение итогового sMAPE.

# %% [markdown]
# ### Тестирование моделей

# %%
model = RandomForestRegressor(random_state=42, n_estimators=70, max_depth=5)
model.fit(features_train, target_train_rougher)
predicted_test = model.predict(features_test)
rougher_smape = smape(target_test_rougher, predicted_test)
rougher_smape
# Out:
# 8.333223913475535

# %%
model = RandomForestRegressor(random_state=42, n_estimators=80, max_depth=4)
model.fit(features_train, target_train_final)
predicted_test = model.predict(features_test)
final_smape = smape(target_test_final, predicted_test)
final_smape
# Out:
# 9.625031723266932

# %% [markdown]
# #### Проверим модель на адекватность (сравнение с DummyRegressor)

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train, target_train_rougher)
predictions = dummy_regr.predict(features_test)
smape(target_test_rougher, predictions)
# Out:
# 9.062804434628053

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train, target_train_final)
predictions = dummy_regr.predict(features_test)
smape(target_test_final, predictions)
# Out:
# 10.082550285254092

# %% [markdown]
# **Вывод:** Можно сказать, что наша модель работает адекватно, так как ее качество действительно превышает наивную модель, которая просто каждому объекту выборки предсказывает среднее значение.

# %% [markdown]
# ### Расчет итогового sMAPE

# %%
# рассчитаем итоговое sMAPE
general_smape = 0.25 * rougher_smape + 0.75 * final_smape
print(f'Итоговое sMAPE: {general_smape}')
# Out:
# Итоговое sMAPE: 9.302079770819084

# %% [markdown]
# **Вывод:** Итоговое sMAPE на тестовой выборке при предсказании выбранными моделями получилось равным 9.3.

# %% [markdown]
# ## Общий вывод по проекту

# %% [markdown]
# **В проекте велась работа с данными, характеристеризующими технологический процесс очистки руды.** Всего 3 датасета: обучающая выборка, тестовая выборка и исходные данные. Каждый объект в наборе данных — это информация об норм параметре на определенном этапе процесса. Наименование признаков следующее: [этап].[тип_параметра].[название_параметра]. Например: rougher.input.feed_ag
#
# Возможные значения для блока **[этап]**:
# - rougher — флотация,
# - primary_cleaner — первичная очистка,
# - secondary_cleaner — вторичная очистка,
# - final — финальные характеристики.
#
# Возможные значения для блока **[тип_параметра]**:
# - input — параметры сырья,
# - output — параметры продукта,
# - state — параметры, характеризующие текущее состояние этапа,
# - calculation — расчётные характеристики.
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
#
# Необходимо смоделировать процесс восстановления золота из золотосодержащей руды. **Основная задача состоит в прогнозирование сразу двух величин: эффективности обогащения чернового концентрата и эффективности обогащения финального концентрата.**
#
# **Как метрика качества в данном проекте использовалась sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).** Итоговое sMAPE для двух предсказаний расчитывалось следующим образом: 25% * sMAPE(rougher) + 75% * sMAPE(final)
#
# **Проведены подготовка и анализ данных:**
# - **заполнены пропуски в данных**: соседние по времени параметры часто похожи, поэтому использовалось заполнение предыдущим значением;
# - **проверка на наличие полных дубликатов** в данных показала, что их нет;
# - **исследованы изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки**;
# - проведено **сравнение распределения размеров гранул сырья на обучающей и тестовой выборках**;
# - **исследована суммарная концентрация всех веществ на разных стадиях**;
# - **найдены признаки недоступные в тестовой выборке**: признаки относятся к типу output или calculation, которые не могут быть получены во время самого процесса. Эти данные описывают полученный продукт или какие-то его характеристики. **Такие данные не должны участвовать в обучении и предсказании и были удалены из обучающей выборки**.
#
# Мы попробовали 3 различные модели: дерево решений, случайный лес и линейную регрессию. У каждой модели мы также меняли гиперпараметры, чтобы добиться наиболее высокой оценки качества. Мы оценивали качество кросс-валидацией.
#
# **По результатам экспериментов лучшие результаты показывает модель случайного леса.**
#
# При оценке качества кросс-валидацией **при предсказании эффективности обогащения чернового концентрата удалось получить значение метрики sMAPE равное 6.5** при следующих гиперпараметрах: максимальная глубина дерева – 5 и количество деревьев – 70.
# При оценке качества кросс-валидацией **при предсказании эффективности обогащения финального концентрата удалось получить значение метрики sMAPE равное 9.0** при следующих гиперпараметрах: максимальная глубина дерева – 4 и количество деревьев – 80.
#
# **Итоговое sMAPE на тестовой выборке при предсказании выбранными моделями получилось равным 9.3.**
